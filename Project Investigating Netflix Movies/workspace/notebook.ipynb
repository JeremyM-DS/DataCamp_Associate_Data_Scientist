# %% [markdown]
# <center><img src="redpopcorn.jpg"></center>

# %% [markdown]
# **Netflix** ! Lancé en 1997 comme service de location de DVD, Netflix est devenu l’une des plus grandes entreprises du divertissement et des médias.
#
# Avec le grand nombre de films et de séries disponibles sur la plateforme, c’est l’occasion idéale de mettre en pratique vos compétences en analyse exploratoire de données et d’explorer l’industrie du divertissement.
#
# Vous travaillez pour une société de production spécialisée dans les styles nostalgiques. Vous souhaitez mener quelques recherches sur les films sortis dans les années 1990. Vous allez plonger dans les données de Netflix et réaliser une analyse exploratoire pour mieux comprendre cette décennie cinématographique incroyable !
#
# Vous disposez du jeu de données `netflix_data.csv`, accompagné du tableau suivant qui détaille les noms de colonnes et leurs descriptions. N’hésitez pas à poursuivre vos explorations après soumission !
#
# ## Les données
# ### **netflix_data.csv**
# | Colonne | Description |
# |--------|-------------|
# | `show_id` | Identifiant du programme |
# | `type` | Type de programme |
# | `title` | Titre du programme |
# | `director` | Réalisateur ou réalisatrice du programme |
# | `cast` | Distribution du programme |
# | `country` | Pays d’origine |
# | `date_added` | Date d’ajout sur Netflix |
# | `release_year` | Année de sortie sur Netflix |
# | `duration` | Durée du programme en minutes |
# | `description` | Description du programme |
# | `genre` | Genre du programme |

# %%
# Importing pandas and matplotlib
import pandas as pd
import matplotlib.pyplot as plt

# Read in the Netflix CSV as a DataFrame
netflix_df = pd.read_csv("netflix_data.csv")

# %%
# Start coding here! Use as many cells as you like

# Filter for movies released in the 1990s
movies_90s = netflix_df[
    (netflix_df["type"] == "Movie") &
    (netflix_df["release_year"] >= 1990) &
    (netflix_df["release_year"] <= 1999)
]

# Most frequent movie duration in the 1990s
duration = int(movies_90s["duration"].mode()[0])

# Count short action movies (< 90 min)
short_action_movies = movies_90s[
    (movies_90s["genre"] == "Action") &
    (movies_90s["duration"] < 90)
]

short_movie_count = len(short_action_movies)

print("Durée la plus fréquente :", duration, " min")
print("Nombre de films d'action courts :", short_movie_count)
# Out:
# Durée la plus fréquente : 94  min
# Nombre de films d'action courts : 7
